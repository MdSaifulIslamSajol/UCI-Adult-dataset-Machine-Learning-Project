# %% [markdown]
# Load Basic Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('AdultData.xlsx')
df.head(10)
# Out:
#    Age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
# 7   52  Self-emp-not-inc  209642    HS-grad              9
# 8   31           Private   45781    Masters             14
# 9   42           Private  159449  Bachelors             13
#
#           marital-status         occupation   relationship   race     Sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3     Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4     Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 5     Married-civ-spouse    Exec-managerial           Wife  White  Female
# 6  Married-spouse-absent      Other-service  Not-in-family  Black  Female
# 7     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 8          Never-married     Prof-specialty  Not-in-family  White  Female
# 9     Married-civ-spouse    Exec-managerial        Husband  White    Male
#
#    Unnamed: 10  Unnamed: 11  hours-per-week native-country salary
# 0         2174            0              40  United-States  <=50K
# 1            0            0              13  United-States  <=50K
# 2            0            0              40  United-States  <=50K
# 3            0            0              40  United-States  <=50K
# 4            0            0              40           Cuba  <=50K
# 5            0            0              40  United-States  <=50K
# 6            0            0              16        Jamaica  <=50K
# 7            0            0              45  United-States   >50K
# 8        14084            0              50  United-States   >50K
# 9         5178            0              40  United-States   >50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.dtypes
# Out:
# Age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# Sex               object
# Unnamed: 10        int64
# Unnamed: 11        int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
df.nunique()
# Out:
# Age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# Sex                   2
# Unnamed: 10         119
# Unnamed: 11          92
# hours-per-week       94
# native-country       42
# salary                2
# dtype: int64

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education-num   32561.0      10.080679       2.572720      1.0       9.0
# Unnamed: 10     32561.0    1077.648844    7385.292085      0.0       0.0
# Unnamed: 11     32561.0      87.303830     402.960219      0.0       0.0
# hours-per-week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education-num       10.0      12.0       16.0
# Unnamed: 10          0.0       0.0    99999.0
# Unnamed: 11          0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0

# %% [markdown]
# ### Value Count Function

# %%
df['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'Sex',
#        'Unnamed: 10', 'Unnamed: 11', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df['occupation'].value_counts()
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df['native-country'].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
df['marital-status'].value_counts()
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: Sex, dtype: int64

# %%
df['race'].value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
df['salary'].value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: salary, dtype: int64

# %%
sns.countplot(df['salary'], palette='coolwarm', hue='relationship', data=df);

# %%
df['education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %% [markdown]
# ### Filling ? values

# %%
#replace the values with mode
df['workclass'] = df['workclass'].replace('?', 'Private')
df['occupation'] = df['occupation'].replace('?', 'Prof-specialty')
df['native-country'] = df['native-country'].replace('?', 'United-States')

# %%
df.head(8)
# Out:
#    Age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
# 7   52  Self-emp-not-inc  209642    HS-grad              9
#
#           marital-status         occupation   relationship   race     Sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3     Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4     Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 5     Married-civ-spouse    Exec-managerial           Wife  White  Female
# 6  Married-spouse-absent      Other-service  Not-in-family  Black  Female
# 7     Married-civ-spouse    Exec-managerial        Husband  White    Male
#
#    Unnamed: 10  Unnamed: 11  hours-per-week native-country salary
# 0         2174            0              40  United-States  <=50K
# 1            0            0              13  United-States  <=50K
# 2            0            0              40  United-States  <=50K
# 3            0            0              40  United-States  <=50K
# 4            0            0              40           Cuba  <=50K
# 5            0            0              40  United-States  <=50K
# 6            0            0              16        Jamaica  <=50K
# 7            0            0              45  United-States   >50K

# %% [markdown]
# ### Feature Engineering

# %%
# education Category
df.education= df.education.replace(['Preschool', '1st-4th', '5th-6th', '7th-8th', '9th','10th', '11th', '12th'], 'school')
df.education = df.education.replace('HS-grad', 'high school')
df.education = df.education.replace(['Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Some-college'], 'higher')
df.education = df.education.replace('Bachelors', 'undergrad')
df.education = df.education.replace('Masters', 'grad')
df.education = df.education.replace('Doctorate', 'doc')

# %%
#martial status
df['marital-status']= df['marital-status'].replace(['Married-civ-spouse', 'Married-AF-spouse'], 'married')
df['marital-status']= df['marital-status'].replace(['Never-married'], 'not-married')
df['marital-status']= df['marital-status'].replace(['Divorced', 'Separated','Widowed',
                                                   'Married-spouse-absent'], 'other')

# %%
# salary
df.salary = df.salary.replace('<=50K', 0)
df.salary = df.salary.replace('>50K', 1)

# %%
df.head()
# Out:
#    Age         workclass  fnlwgt    education  education-num marital-status  \
# 0   39         State-gov   77516    undergrad             13    not-married
# 1   50  Self-emp-not-inc   83311    undergrad             13        married
# 2   38           Private  215646  high school              9          other
# 3   53           Private  234721       school              7        married
# 4   28           Private  338409    undergrad             13        married
#
#           occupation   relationship   race     Sex  Unnamed: 10  Unnamed: 11  \
# 0       Adm-clerical  Not-in-family  White    Male         2174            0
# 1    Exec-managerial        Husband  White    Male            0            0
# 2  Handlers-cleaners  Not-in-family  White    Male            0            0
# 3  Handlers-cleaners        Husband  Black    Male            0            0
# 4     Prof-specialty           Wife  Black  Female            0            0
#
#    hours-per-week native-country  salary
# 0              40  United-States       0
# 1              13  United-States       0
# 2              40  United-States       0
# 3              40  United-States       0
# 4              40           Cuba       0

# %%
df['marital-status'].value_counts()
# Out:
# married        14999
# not-married    10683
# other           6879
# Name: marital-status, dtype: int64

# %%
df['education'].value_counts()
# Out:
# high school    10501
# higher         10316
# undergrad       5355
# school          4253
# grad            1723
# doc              413
# Name: education, dtype: int64

# %%
df.corr()
# Out:
#                      Age    fnlwgt  education-num  Unnamed: 10  Unnamed: 11  \
# Age             1.000000 -0.076646       0.036527     0.077674     0.057775
# fnlwgt         -0.076646  1.000000      -0.043195     0.000432    -0.010252
# education-num   0.036527 -0.043195       1.000000     0.122630     0.079923
# Unnamed: 10     0.077674  0.000432       0.122630     1.000000    -0.031615
# Unnamed: 11     0.057775 -0.010252       0.079923    -0.031615     1.000000
# hours-per-week  0.068756 -0.018768       0.148123     0.078409     0.054256
# salary          0.234037 -0.009463       0.335154     0.223329     0.150526
#
#                 hours-per-week    salary
# Age                   0.068756  0.234037
# fnlwgt               -0.018768 -0.009463
# education-num         0.148123  0.335154
# Unnamed: 10           0.078409  0.223329
# Unnamed: 11           0.054256  0.150526
# hours-per-week        1.000000  0.229689
# salary                0.229689  1.000000

# %%
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# ### Histogram

# %%
df.hist(figsize=(12,12), layout=(3,3), sharex=False);

# %% [markdown]
# ### BoxPlot

# %%
df.plot(kind='box', figsize=(12,12), layout=(3,3), sharex=False, subplots=True);

# %% [markdown]
# ### Plotly

# %%
px.pie(df, values='education-num', names='education', title='% of edu', 
      color_discrete_sequence = px.colors.qualitative.T10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="635ac893-911b-4999-acf5-9a2231a23c40" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("635ac893-911b-4999-acf5-9a2231a23c40")) {                    Plotly.newPlot(                        "635ac893-911b-4999-acf5-9a2231a23c40",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"education=%{label}<br>education-num=%{value}<extra></extra>","labels":["undergrad","undergrad","high school","school","undergrad","grad","school","high school","grad","undergrad","higher","undergrad","undergrad","higher","higher","school","high school","high school","school","grad","doc","high school","school","school","high school","undergrad","high school","higher","high school","high school","higher","higher","undergrad","higher","higher","school","higher","high school","higher","higher","school","undergrad","undergrad","high school","high school","undergrad","high school","grad","higher","higher","higher","high school","higher","undergrad","high school","higher","school","higher","high school","high school","undergrad","school","high school","doc","higher","high school","higher","high school","higher","higher","higher","undergrad","undergrad","higher","higher","high school","higher","school","school","school","high school","undergrad","high school","high school","high school","high school","high school","grad","school","doc","higher","higher","higher","high school","undergrad","higher","doc","higher","higher","high school","grad","undergrad","grad","higher","high school","high school","school","school","high school","high school","undergrad","higher","high school","higher","high school","school","higher","higher","higher","high school","higher","undergrad","undergrad","undergrad","higher","undergrad","higher","higher","high school","higher","higher","high school","high school","undergrad","higher","grad","high school","higher","higher","higher","high school","higher","higher","higher","higher","high school","higher","high school","school","higher","higher","high school","undergrad","high school","high school","high school","undergrad","higher","high school","undergrad","school","high school","grad","high school","grad","higher","higher","grad","school","higher","high school","high school","higher","undergrad","undergrad","high school","high school","high school","high school","undergrad","higher","higher","higher","school","higher","high school","undergrad","undergrad","grad","doc","higher","higher","undergrad","higher","undergrad","school","higher","grad","grad","high school","grad","high school","undergrad","higher","high school","school","undergrad","high school","high school","school","high school","high school","higher","high school","school","undergrad","higher","undergrad","undergrad","school","higher","school","high school","high school","school","high school","school","high school","higher","high school","school","high school","higher","higher","higher","high school","higher","undergrad","grad","high school","undergrad","high school","higher","higher","higher","high school","high school","high school","higher","high school","higher","undergrad","school","higher","higher","high school","high school","high school","higher","school","undergrad","high school","school","higher","school","higher","higher","high school","undergrad","high school","high school","school","grad","grad","high school","high school","higher","higher","higher","higher","undergrad","higher","higher","undergrad","high school","grad","higher","higher","undergrad","school","undergrad","high school","undergrad","higher","undergrad","high school","undergrad","grad","high school","high school","undergrad","higher","high school","high school","higher","high sch ...

# %%
sns.countplot(df['education'], hue='Sex', data=df, palette='seismic');

# %% [markdown]
# ## Model building

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df1= df.copy()
df1= df1.apply(LabelEncoder().fit_transform)
df1.head()
# Out:
#    Age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   22          6    2671          5             12               1
# 1   33          5    2926          5             12               0
# 2   21          3   14086          2              8               2
# 3   36          3   15336          4              6               0
# 4   11          3   19355          5             12               0
#
#    occupation  relationship  race  Sex  Unnamed: 10  Unnamed: 11  \
# 0           0             1     4    1           25            0
# 1           3             0     4    1            0            0
# 2           5             1     4    1            0            0
# 3           5             0     2    1            0            0
# 4           9             5     2    0            0            0
#
#    hours-per-week  native-country  salary
# 0              39              38       0
# 1              12              38       0
# 2              39              38       0
# 3              39              38       0
# 4              39               4       0

# %%
ss= StandardScaler().fit(df1.drop('salary', axis=1))

# %%
X= ss.transform(df1.drop('salary', axis=1))
y= df['salary']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=40)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr = LogisticRegression()

model = lr.fit(X_train, y_train)
prediction = model.predict(X_test)

print("Acc on training data: {:,.3f}".format(lr.score(X_train, y_train)))
print("Acc on test data: {:,.3f}".format(lr.score(X_test, y_test)))
# Out:
# Acc on training data: 0.840
# Acc on test data: 0.833

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

model1 = rfc.fit(X_train, y_train)
prediction1 = model1.predict(X_test)

print("Acc on training data: {:,.3f}".format(rfc.score(X_train, y_train)))
print("Acc on test data: {:,.3f}".format(rfc.score(X_test, y_test)))
# Out:
# Acc on training data: 1.000
# Acc on test data: 0.855

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print(confusion_matrix(y_test, prediction1))
# Out:
# [[6877  520]
#  [ 900 1472]]

# %%
print(classification_report(y_test, prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91      7397
#            1       0.74      0.62      0.67      2372
#
#     accuracy                           0.85      9769
#    macro avg       0.81      0.78      0.79      9769
# weighted avg       0.85      0.85      0.85      9769

# %%
#Precision: tp/tp+fp

print('Precision =' , 10332/(10332+1286))
# Out:
# Precision = 0.8893096918574626

# %%
# recall= tp/tp+fn

print('Recall =', 10332/(10332+806))
# Out:
# Recall = 0.9276351230023343

# %% [markdown]
# ### for other class : 1 (>50K)

# %%
print('Precision = ', 2229/(2229+806))
# Out:
# Precision =  0.7344316309719934

# %%
print('Recall= ', 2229/(2229+1286))
# Out:
# Recall=  0.6341394025604552
